# %% [markdown]
# <a href="https://colab.research.google.com/github/mendiang/IYKRA-Data-Science-Fellowship-Batch-6/blob/main/Metal_Surface_Defects_NEU_DET_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. About the dataset

# %% [markdown]
# This dataset was downloaded from NEU Metal Surface Defects Databse which contains six kinds of typical surface defects of the hot-rolled steel strip are collected, i.e., rolled-in scale (RS), patches (Pa), crazing (Cr), pitted surface (PS), inclusion (In) and scratches (Sc). The database includes 1,800 grayscale images: 300 samples each of six different kinds of typical surface defects. The detailed defects are as follows:
#
#
# *   **Inclusion**: Inclusion is a typical defect of metal surface defects. Some inclusions are loose and easy to fall off, some pressed into the plate.
# *   **Crazing**: Crazing is the phenomenon that produces some cracks on the surface of a material.
# *   **Patches**: A part of metal marked out from the rest by a particular characteristic.
# *   **Pitted surface**: Pitting is a form of corrosion that focuses on a very small range of metal surfaces and penetrates into the metal interior. Pitting is generally small in diameter but deep in depth.
# *   **Scratches**: A scratch is a mark of abrasion on a surface.
# *   **Rolled in scale**: A rolled-in scale defect occurs when the mill scale is rolled into the metal duringthe rolling process.
#
# The dataset divided into 3 directories. The training directory contains 276 images of each class from the 300 images. The rest 24 images of each class also divided into tests and valid datasets.

# %% [markdown]
# #2. Import Library

# %%
import os
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.datasets import load_files

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.preprocessing.image import array_to_img, img_to_array, load_img

# %% [markdown]
# # 3. Set Up Kaggle API

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2ecc508a-fce0-47c6-839e-19252cf2f1ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ecc508a-fce0-47c6-839e-19252cf2f1ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"imammukhri","key":"eb9766ded639cf23df08187c5e57f8e0"}'}

# %%
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 66 Jul 30 20:13 kaggle.json

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# #4. Load the data from dataset

# %%
# !kaggle datasets download -d fantacher/neu-metal-surface-defects-data
# Out:
# Downloading neu-metal-surface-defects-data.zip to /content
#  87% 50.0M/57.4M [00:00<00:00, 247MB/s]
# 100% 57.4M/57.4M [00:00<00:00, 227MB/s]

# %%
# !unzip /content/neu-metal-surface-defects-data.zip
# Out:
# Archive:  /content/neu-metal-surface-defects-data.zip
#   inflating: NEU Metal Surface Defects Data/Thumbs.db
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_1.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_10.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_100.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_101.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_102.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_103.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_104.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_105.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_106.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_107.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_108.bmp
#   inflating: NEU Metal Surface Defects Data/test/Crazing/Cr_109.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_1.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_10.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_100.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_101.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_102.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_103.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_104.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_105.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_106.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_107.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_108.bmp
#   inflating: NEU Metal Surface Defects Data/test/Inclusion/In_109.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_1.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_10.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_100.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_101.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_102.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa_103.bmp
#   inflating: NEU Metal Surface Defects Data/test/Patches/Pa
bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_26.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_260.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_261.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_262.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_263.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_264.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_265.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_266.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_267.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_268.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_269.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_27.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_270.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_271.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_272.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_273.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_274.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_275.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_276.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_277.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_278.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_279.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_28.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_280.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_281.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_282.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_283.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_284.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_285.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_286.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_287.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_288.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_289.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_29.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_290.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_291.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_292.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_293.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_294.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_295.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_296.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_297.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_298.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_299.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_3.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_30.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_300.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_31.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_32.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_33.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_34.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_35.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_36.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_37.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_38.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_39.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_4.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_40.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_41.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_42.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_43.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_44.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_45.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_46.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_47.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_48.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_49.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_5.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_50.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_51.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_52.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_53.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_54.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_55.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_56.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_57.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_58.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_59.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_6.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_60.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_61.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_62.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_63.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_64.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_65.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_66.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_67.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_68.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_69.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_7.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_70.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_71.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_72.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_73.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_74.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_75.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_76.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_77.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_78.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_79.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_8.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_80.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_81.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_82.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_83.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_84.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_85.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_86.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_87.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_88.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_89.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_9.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_90.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_91.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_92.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_93.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_94.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_95.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_96.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_97.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_98.bmp
#   inflating: NEU Metal Surface Defects Data/train/Scratches/Sc_99.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Crazing/Cr_12.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Inclusion/In_12.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Patches/Pa_12.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Pitted/PS_12.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Rolled/RS_12.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_11.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_110.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_111.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_112.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_113.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_114.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_115.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_116.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_117.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_118.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_119.bmp
#   inflating: NEU Metal Surface Defects Data/valid/Scratches/Sc_12.bmp

# %%
train_dir = '/content/NEU Metal Surface Defects Data/train'
val_dir = '/content/NEU Metal Surface Defects Data/valid'
test_dir='/content/NEU Metal Surface Defects Data/test'
print("Path Direcorty: ",os.listdir("/content/NEU Metal Surface Defects Data"))
print("Train Direcorty: ",os.listdir("/content/NEU Metal Surface Defects Data/train"))
print("Test Direcorty: ",os.listdir("/content/NEU Metal Surface Defects Data/test"))
print("Validation Direcorty: ",os.listdir("/content/NEU Metal Surface Defects Data/valid"))
# Out:
# Path Direcorty:  ['valid', 'train', 'test', 'Thumbs.db']
# Train Direcorty:  ['Crazing', 'Scratches', 'Patches', 'Rolled', 'Inclusion', 'Pitted']
# Test Direcorty:  ['Crazing', 'Scratches', 'Patches', 'Rolled', 'Inclusion', 'Pitted']
# Validation Direcorty:  ['Crazing', 'Scratches', 'Patches', 'Rolled', 'Inclusion', 'Pitted']

# %% [markdown]
# We can see the dataset distribution for 'Inclusion' surface defect. Rest of the dataset also follow the same distribution

# %%
print("Training Inclusion data:",len(os.listdir(train_dir+'/'+'Inclusion')))

print("Testing Inclusion data:",len(os.listdir(test_dir+'/'+'Inclusion')))

print("Validation Inclusion data:",len(os.listdir(val_dir+'/'+'Inclusion')))
# Out:
# Training Inclusion data: 276
# Testing Inclusion data: 12
# Validation Inclusion data: 12

# %% [markdown]
# #5. Data preprocessing

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)


test_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 10 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(200, 200),
        batch_size=10,
        class_mode='categorical')

# Flow validation images in batches of 10 using test_datagen generator
validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(200, 200),
        batch_size=10,
        class_mode='categorical')
# Out:
# Found 1656 images belonging to 6 classes.
# Found 72 images belonging to 6 classes.

# %%
#Using transfer learning
from tensorflow.keras.applications import xception
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
base_model = tf.keras.applications.xception.Xception(
    weights='imagenet', # Load weights pre-trained on ImageNet.
    include_top=False,  # Do not include the ImageNet classifier at the top.
    input_shape=(200,200,3),
    pooling='avg')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step

# %% [markdown]
# ![Transfer-learning-idea.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Transfer learning is about leveraging feature representations from a pre-trained model, so you don’t have to train a new model from scratch.
#
# The pre-trained models are usually trained on massive datasets that are a standard benchmark in the computer vision frontier. The weights obtained from the models can be reused in other computer vision tasks.
#
# These models can be used directly in making predictions on new tasks or integrated into the process of training a new model. Including the pre-trained models in a new model leads to lower training time and lower generalization error.
#
# Transfer learning is particularly very useful when you have a small training dataset. In this case, you can, for example, use the weights from the pre-trained models to initialize the weights of the new model.

# %% [markdown]
# #6. Feature extraction

# %% [markdown]
# In this step, you will freeze the convolutional base created from the previous step and to use as a feature extractor. Additionally, you add a classifier on top of it and train the top-level classifier.

# %% [markdown]
# ###Freeze the convolutional base

# %% [markdown]
# It is important to freeze the convolutional base before you compile and train the model. Freezing (by setting layer.trainable = False) prevents the weights in a given layer from being updated during training. Xception has many layers, so setting the entire model's trainable flag to False will freeze all of them.

# %%
base_model.trainable = False # Freeze the base_model

# %% [markdown]
# ![Fine-tuning-pretrained-network.png](data:image/png;base64,...)

# %%
# Let's take a look at the base model architecture
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 99, 99, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 99, 99, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 99, 99, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 97, 97, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 97, 97, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 97, 97, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 97, 97, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 97, 97, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 97, 97, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 97, 97, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 97, 97, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 49, 49, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 49, 49, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 49, 49, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 49, 49, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 49, 49, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 49, 49, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 49, 49, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 49, 49, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 49, 49, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 49, 49, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 25, 25, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 25, 25, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 25, 25, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 25, 25, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 25, 25, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 25, 25, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 25, 25, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 25, 25, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 25, 25, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 13, 13, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 13, 13, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 13, 13, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 13, 13, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 13, 13, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 13, 13, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 13, 13, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 13, 13, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 13, 13, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 13, 13, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 13, 13, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 13, 13, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 13, 13, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 13, 13, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 13, 13, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 13, 13, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 13, 13, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 13, 13, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 13, 13, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 13, 13, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 13, 13, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 13, 13, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 13, 13, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 13, 13, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 13, 13, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 13, 13, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 13, 13, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 13, 13, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 13, 13, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 13, 13, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 13, 13, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 13, 13, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 13, 13, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 13, 13, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 13, 13, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 13, 13, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 13, 13, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 13, 13, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 13, 13, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 13, 13, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 13, 13, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 13, 13, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 13, 13, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 7, 7, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 7, 7, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 7, 7, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 7, 7, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 7, 7, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 7, 7, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 7, 7, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# ###Add a classification head

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(6, activation='softmax'))

# %% [markdown]
# ###Compile the model

# %% [markdown]
# Compile the model before training it. Since there are more than two classes, use a categorical_crossentropy

# %%
model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 21,913,646
# Trainable params: 1,052,166
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# Stop training the model at 98% traning accuracy

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > 0.98 ):
            print("\nReached 98% accuracy so cancelling training!")
            self.model.stop_training = True

# %% [markdown]
# ###Train the model

# %%
initial_epochs = 10
loss0, accuracy0 = model.evaluate(validation_generator)

print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# 8/8 [==============================] - 32s 102ms/step - loss: 1.9006 - accuracy: 0.1667
# initial loss: 1.90
# initial accuracy: 0.17

# %%
callbacks = myCallback()
history = model.fit(train_generator, epochs=initial_epochs,
                    validation_data=validation_generator, callbacks=[callbacks],
                    verbose=1, shuffle=True)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 21s 111ms/step - loss: 0.2643 - accuracy: 0.9203 - val_loss: 0.0553 - val_accuracy: 0.9722
# Epoch 2/10
# 166/166 [==============================] - 18s 108ms/step - loss: 0.0778 - accuracy: 0.9728 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 3/10
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0436 - accuracy: 0.9885 - val_loss: 0.0385 - val_accuracy: 0.9861
#
# Reached 98% accuracy so cancelling training!

# %% [markdown]
# ###Learning Curves
# Let's take a look at the learning curves of the training and validation accuracy/loss when using the Exception base model as a fixed feature extractor.

# %%
from matplotlib.ticker import StrMethodFormatter

plt.figure(figsize=(8, 8))

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


# summarize history for accuracy  
plt.subplot(211)  
plt.plot(acc)  
plt.plot(val_acc)  
plt.title('Model Accuracy')  
plt.ylabel('Accuracy') 
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) # 2 decimal places 
plt.xlabel('Epoch')  
plt.legend(['train', 'test'], loc='lower right')  

plt.figure(figsize=(8, 8)) 

# summarize history for loss     
plt.subplot(212)  
plt.plot(loss)  
plt.plot(val_loss)  
plt.title('Model Loss')  
plt.ylabel('Loss') 
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}')) # 2 decimal places 
plt.xlabel('Epoch')  
plt.legend(['train', 'test'], loc='upper right')  
plt.show()

# %%
from keras.models import load_model
model.save('my_model.h5') # save the entire model with trained weights
new_model = load_model('my_model.h5') # load this model with its weights
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# #7. Fine tuning

# %% [markdown]
# ![Transfer-learning-vs-fine-tuning.png](data:image/png;base64,...)

# %% [markdown]
# Fine-tuning is an optional step in transfer learning. Fine-tuning will usually improve the performance of the model. However, since you have to retrain the entire model, you’ll likely overfit. Overfitting is avoidable. Just retrain the model or part of it using a low learning rate. This is important because it prevents significant updates to the gradient. These updates result in poor performance. Using a callback to stop the training process when the model has stopped improving is also helpful.

# %% [markdown]
# In the feature extraction experiment, you were only training a few layers on top of an Exception base model. The weights of the pre-trained network were not updated during training.
#
# One way to increase performance even further is to train (or "fine-tune") the weights of the top layers of the pre-trained model alongside the training of the classifier you added. The training process will force the weights to be tuned from generic feature maps to features associated specifically with the dataset.
#
# Also, you should try to fine-tune a small number of top layers rather than the whole Exception model. In most convolutional networks, the higher up a layer is, the more specialized it is. The first few layers learn very simple and generic features that generalize to almost all types of images. As you go higher up, the features are increasingly more specific to the dataset on which the model was trained. The goal of fine-tuning is to adapt these specialized features to work with the new dataset, rather than overwrite the generic learning.

# %% [markdown]
# ###Un-freeze the top layers of the model
# All you need to do is unfreeze the base_model and set the bottom layers to be un-trainable. Then, you should recompile the model (necessary for these changes to take effect), and resume training.

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in new_model.layers[:fine_tune_at]:
    layer.trainable =  False
# Out:
# Number of layers in the base model:  133

# %% [markdown]
# ###Compile the model
# As you are training a much larger model and want to readapt the pretrained weights, it is important to use a lower learning rate at this stage. Otherwise, your model could overfit very quickly.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),  # Low learning rate
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 2048)              20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 21,913,646
# Trainable params: 1,052,166
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

#learning_rate reduce module
lr_reduce = keras.callbacks.ReduceLROnPlateau('val_loss', patience=4, 
                                              factor=0.5, min_lr=1e-6)

# Stop early if model doesn't improve after n epochs
early_stopper = EarlyStopping(monitor='val_loss', patience=4,
                              verbose=0, restore_best_weights=True)

# %%
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_generator,
                         batch_size = 32,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_generator,
                         callbacks=[lr_reduce, early_stopper],
                         verbose=1, shuffle=True)
# Out:
# Epoch 3/20
# 166/166 [==============================] - 21s 113ms/step - loss: 0.0541 - accuracy: 0.9837 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 4/20
# 166/166 [==============================] - 18s 109ms/step - loss: 0.0372 - accuracy: 0.9879 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 5/20
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 6/20
# 166/166 [==============================] - 17s 102ms/step - loss: 0.0282 - accuracy: 0.9934 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 7/20
# 166/166 [==============================] - 18s 109ms/step - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 8/20
# 166/166 [==============================] - 18s 109ms/step - loss: 0.0249 - accuracy: 0.9897 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 9/20
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0247 - accuracy: 0.9934 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 10/20
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0221 - accuracy: 0.9940 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 11/20
# 166/166 [==============================] - 18s 110ms/step - loss: 0.0213 - accuracy: 0.9946 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 12/20
# 166/166 [==============================] - 18s 106ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 13/20
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0238 - accuracy: 0.9921 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 14/20
# 166/166 [==============================] - 17s 104ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 15/20
# 166/166 [==============================] - 18s 110ms/step - loss: 0.0192 - accuracy: 0.9946 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 16/20
# 166/166 [==============================] - 18s 108ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 17/20
# 166/166 [==============================] - 18s 110ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 18/20
# 166/166 [==============================] - 17s 103ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 19/20
# 166/166 [==============================] - 17s 102ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 20/20
# 166/166 [==============================] - 18s 107ms/step - loss: 0.0195 - accuracy: 0.9946 - val_loss: 0.0135 - val_accuracy: 1.0000

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.96, 1.01])
plt.plot([initial_epochs-8,initial_epochs-8],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy') 
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # 3 decimal places 
plt.xlabel('Epoch')

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 0.1])
plt.plot([initial_epochs-8,initial_epochs-8],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.ylabel('Loss') 
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # 3 decimal places 
plt.xlabel('Epoch')
plt.show()

# %%
# First, we are going to load the file names and their respective target labels into numpy array! 
def load_dataset(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels
    
x_test, y_test,target_labels = load_dataset(test_dir)

# %%
no_of_classes = len(np.unique(y_test))
no_of_classes
# Out:
# 6

# %%
y_test = np_utils.to_categorical(y_test,no_of_classes)

# %%
# We just have the file names in the x set. Let's load the images and convert them into array.
def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        # Convert to Numpy Array
        images_as_array.append(img_to_array(load_img(file)))
    return images_as_array

x_test = np.array(convert_image_to_array(x_test))
print('Test set shape : ',x_test.shape)
# Out:
# Test set shape :  (72, 200, 200, 3)

# %%
x_test = x_test.astype('float32')/255

# %%
# Let's visualize test prediction.
y_pred = model.predict(x_test)

# plot a raandom sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(16, 9))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=16, replace=False)):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_pred[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("Pred: {}|Act: {}".format(target_labels[pred_idx], target_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %% [markdown]
# ![Scracth.png](data:image/png;base64,...)

# %% [markdown]
# We test our model with one sample metal defect product from one of metal company in Indonesia to predict the type of defect from this above picture. This sample already classified as scratch defect surface by quality control of its company.

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
 
# load the image
img = load_img('Scracth.png', target_size=(200, 200))
# convert to array
img = img_to_array(img)
# reshape into a single sample with 3 channels
img = img.reshape(1, 200, 200, 3)
# center pixel data
img = img.astype('float32')/255
 
# predict the class
result = model.predict(img)
print('This metal has',target_labels[np.argmax(result)])
# Out:
# This metal has Scratches
